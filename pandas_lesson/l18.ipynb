# %%
# coding=utf-8
"""
18 pandas plot

pandas 的 plot 是基于 matplotlib 模块的.
所以如果你用过 matplotlib, pandas 的可视化功能,你也很容易上手.
视频里提到了两种 plot 的方式,其他种的和这两种的运用方式类似,大家可以自学其他的,应该会更容易上手.

plot的图形种类
bar, hist, box, kde, area, scatter, hexbin
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Series
data = pd.Series(data=np.random.randn(1000), index=np.arange(1000))
data = data.cumsum()  # 累加
data.plot()
plt.show()

# %%
data1 = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000),
                     columns=list('ABCD'))
data1 = data1.cumsum()  # 累加
print(data1.head())
data1.plot()
plt.show()
# 有4组数据
# Out:
#           A         B         C         D
# 0 -1.723338  0.605006 -0.716354 -1.026607
# 1 -1.576980  0.079231 -1.418242 -1.839327
# 2  0.090883  1.398214 -1.977646 -0.541026
# 3  1.425570  2.146299 -0.786321 -1.772746
# 4  0.894957  1.178224  0.403756 -1.754247

# %%
data2 = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000),
                     columns=list('ABCD'))
data2 = data1.cumsum()

# scatter 只有两个数据
ax = data2.plot.scatter(x='A', y='B', color='Blue', label='Class 1')  
data2.plot.scatter(x='A', y='C', color='Red', label='Class 2', ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5acf4c82ca6> in <module>()
# ----> 1 data2 = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000),
#       2                      columns=list('ABCD'))
#       3 data2 = data1.cumsum()
#       4
#       5 # scatter 只有两个数据
#
# NameError: name 'pd' is not defined
